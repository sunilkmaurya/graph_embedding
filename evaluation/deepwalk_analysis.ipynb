# %%
#import libraries and set path of data and embeddings
import networkx as nx
import numpy as np
import pickle
from util_func import *

from prettytable import PrettyTable
emb_location = './../generated_embedding/'
graph_location = './../data/'
# Out:
# Warning: graph_tool module is missing

# %%
def run_embed(dataset_name,save_stats=True):
    '''Load the embeddings and perform statistical analysis of predictions'''
    #load the embedding file for the dataset
    emb_loc = emb_location+dataset_name+'.edges_deepwalk.embeddings'
    emb = load_embeddings(emb_loc)
    #runnning simple classifier on deepwalk embeddings
    simple_classify_f1(dataset_name,emb,splits_ratio=[0.1],save_stats=True)
    graph_classify_analysis(dataset_name,graph_stat=True)

# %%
#one time file to create labels for the dataset
from sklearn.preprocessing import MultiLabelBinarizer
def dump_label(data):
    print(f"Dataset is {data}")
    f = open(graph_location+data+'.data','rb')
    a = pickle.load(f)
    print(a)
    if data=='blogcatalog':
        labels = a['LILLabels']
    else:
        labels = a['Labels']
        labels = MultiLabelBinarizer().fit_transform(labels.reshape(labels.shape[0], 1))
    with open(graph_location+data+'.labels',"wb") as f1:
        pickle.dump(labels,f1)
        print(f"{data} labels created")
        
d = ['citeseer','cora','blogcatalog']

for i in d:
    dump_label(i)
# Out:
# Dataset is citeseer
# {'Labels': array([0, 0, 0, ..., 4, 3, 5]), 'NXGraph': <networkx.classes.digraph.DiGraph object at 0x7f1d9838bac8>, 'CSRFeatures': <3327x3703 sparse matrix of type '<class 'numpy.int64'>'
# 	with 105165 stored elements in Compressed Sparse Row format>}
# citeseer labels created
# Dataset is cora
# {'Labels': array([2, 5, 0, ..., 3, 3, 2]), 'CSRFeatures': <2708x1433 sparse matrix of type '<class 'numpy.int64'>'
# 	with 49216 stored elements in Compressed Sparse Row format>, 'NXGraph': <networkx.classes.digraph.DiGraph object at 0x7f1d98718b00>}
# cora labels created
# Dataset is blogcatalog
# {'LILLabels': <10312x39 sparse matrix of type '<class 'numpy.int64'>'
# 	with 14476 stored elements in LInked List format>, 'NXGraph': <networkx.classes.graph.Graph object at 0x7f1d98313198>}
# blogcatalog labels created

# %%
#Analysis for Citeseer Dataset
dataset = 'citeseer'
run_embed(dataset)
# Out:
# file saved
# Embedding dim: 128, graph: citeseer
#
# Run number 1:
# Train ratio: 0.9
# micro: 0.5885885885885885
# macro: 0.4798335584661983
# samples: 0.5885885885885885
# weighted: 0.5958909456077889
# Accuracy: 0.5885885885885885
#
# Graph is citeseer:
# Graph has 3327 and edges are 4676
# +------------+----------+---------------+-----------------+--------+----------------+----------------+
# | Serial No. | Node no. |   True Label  | Predicted Label | Degree | Neighbor label | Neighbor Match |
# +------------+----------+---------------+-----------------+--------+----------------+----------------+
# |     1      |   2168   | (array([6]),) |  (array([4]),)  |   1    | (array([1]),)  |     False      |
# |     2      |   1739   | (array([5]),) |  (array([1]),)  |   1    | (array([5]),)  |      True      |
# |     3      |   1771   | (array([3]),) |  (array([5]),)  |   1    | (array([3]),)  |      True      |
# |     4      |   2209   | (array([2]),) |  (array([5]),)  |   1    | (array([2]),)  |      True      |
# |     5      |   3233   | (array([6]),) |  (array([2]),)  |   1    | (array([6]),)  |      True      |
# |     6      |    22    | (array([1]),) |  (array([5]),)  |   1    | (array([1]),)  |      True      |
# |     7      |   1412   | (array([2]),) |  (array([4]),)  |   1    | (array([2]),)  |      True      |
# |     8      |   1197   | (array([2]),) |  (array([3]),)  |   1    | (array([3]),)  |     False      |
# |     9      |   1953   | (array([3]),) |  (array([5]),)  |   1    | (array([3]),)  |      True      |
# |     10     |   499    | (array([3]),) |  (array([5]),)  |   1    | (array([3]),)  |      True      |
# |     11     |   3207   | (array([3]),) |  (array([1]),)  |   1    | (array([3]),)  |      True      |
# |     12     |   1721   | (array([2]),) |  (array([3]),)  |   1    | (array([2]),)  |      True      |
# |     13     |   2025   | (array([4]),) |  (array([3]),)  |   1    | (array([3]),)  |     False      |
# |     14     |   3322   | (array([5]),) |  (array([3]),)  |   1    | (array([4]),)  |     False      |
# |     15     |   675    | (array([4]),) |  (array([3]),)  |   1    | (array([2]),)  |     False      |
# |     16     |   2540   | (array([5]),) |  (array([3]),)  |   1    | (array([5]),)  |      True      |
# |     17     |   3312   | (array([5]),) |  (array([4]),)  |   1    | (array([5]),)  |      True      |
# |     18     |   628    | (array([4]),) |  (array([3]),)  |   1    | (array([4]),)  |      True      |
# |     19     |   2445   | (array([4]),) |  (array([1]),)  |   1    | (array([4]),)  |      True      |
# |     20     |   2638   | (array([6]),) |  (array([3]),)  |   1    | (array([6]),)  |      True      |
# |     21     |   514    | (array([3]),) |  (array([4]),)  |   1    | (array([3]),)  |      True      |
# |     22     |   1171   | (array([2]),) |  (array([4]),)  |   1    | (array([5]),)  |     False      |
# |     23     |    92    | (array([4]),) |  (array([3]),)  |   1    | (array([4]),)  |      True      |
# |     24     |   1014   | (array([5]),) |  (array([6]),)  |   1    | (array([5]),)  |      True      |
# |     25     |   2566   | (array([5]),) |  (array([1]),)  |   1    | (array([2]),)  |     False      |
# |     26     |   3275   | (array([5]),) |  (array([4]),)  |   1    | (array([5]),)  |      True      |
# |     27     |   224    | (array([3]),) |  (array([6]),)  |   1    | (array([3]),)  |      True      |
# |     28     |   3041   | (array([3]),) |  (array([0]),)  |   1    | (array([2]),)  |     False      |
# |     29     |   3311   | (array([3]),) |  (array([5]),)  |   1    | (array([3]),)  |      True      |
# |     30     |   1489   | (array([3]),) |  (array([6]),)  |   1    | (array([3]),)  |      True      |
# |     31     |   3213   | (array([5]),) |  (array([2]),)  |   1    | (array([5]),)  |      True      |
# |     32     |   3174   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     33     |   311    | (array([6]),) |  (array([3]),)  |   1    | (array([5]),)  |     False      |
# |     34     |   643    | (array([3]),) |  (array([5]),)  |   1    | (array([3]),)  |      True      |
# |     35     |   1357   | (array([1]),) |  (array([3]),)  |   1    | (array([1]),)  |      True      |
# |     36     |   1693   | (array([6]),) |  (array([4]),)  |   1    | (array([6]),)  |      True      |
# |     37     |   2147   | (array([6]),) |  (array([4]),)  |   1    | (array([6]),)  |      True      |
# |     38     |   923    | (array([4]),) |  (array([3]),)  |   1    | (array([4]),)  |      True      |
# |     39     |   936    | (array([5]),) |  (array([3]),)  |   1    | (array([5]),)  |      True      |
# |     40     |   3070   | (array([2]),) |  (array([6]),)  |   1    | (array([2]),)  |      True      |
# |     41     |   3313   | (array([5]),) |  (array([4]),)  |   1    | (array([5]),)  |      True      |
# |     42     |   1767   | (array([3]),) |  (array([5]),)  |   1    | (array([3]),)  |      True      |
# |     43     |   3080   | (array([3]),) |  (array([4]),)  |   1    | (array([3]),)  |      True      |
# |     44     |   2710   | (array([4]),) |  (array([5]),)  |   1    | (array([2]),)  |     False      |
# |     45     |   3245   | (array([4]),) |  (array([5]),)  |   1    | (array([4]),)  |      True      |
# |     46     |   3122   | (array([2]),) |  (array([5]),)  |   1    | (array([5]),)  |     False      |
# |     47     |   3139   | (array([6]),) |  (array([3]),)  |   1    | (array([6]),)  |      True      |
# |     48     |   686    | (array([4]),) |  (array([3]),)  |   1    | (array([3]),)  |     False      |
# |     49     |   3107   | (array([4]),) |  (array([6]),)  |   1    | (array([4]),)  |      True      |
# |     50     |   2784   | (array([1]),) |  (array([4]),)  |   1    | (array([1]),)  |      True      |
# |     51     |   1255   | (array([5]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     52     |   3010   | (array([3]),) |  (array([5]),)  |   1    | (array([3]),)  |      True      |
# |     53     |   3144   | (array([6]),) |  (array([5]),)  |   1    | (array([3]),)  |     False      |
# |     54     |   2874   | (array([2]),) |  (array([6]),)  |   1    | (array([6]),)  |     False      |
# |     55     |   2102   | (array([5]),) |  (array([3]),)  |   1    | (array([4]),)  |     False      |
# |     56     |   2984   | (array([3]),) |  (array([5]),)  |   1    | (array([3]),)  |      True      |
# |     57     |   3068   | (array([3]),) |  (array([4]),)  |   1    | (array([3]),)  |      True      |
# |     58     |   316    | (array([3]),) |  (array([6]),)  |   1    | (array([3]),)  |      True      |
# |     59     |   517    | (array([3]),) |  (array([6]),)  |   1    | (array([3]),)  |      True      |
# |     60     |   3160   | (array([6]),) |  (array([3]),)  |   1    | (array([6]),)  |      True      |
# |     61     |   1865   | (array([4]),) |  (array([3]),)  |   1    | (array([4]),)  |      True      |
# |     62     |   1801   | (array([4]),) |  (array([3]),)  |   1    | (array([6]),)  |     False      |
# |     63     |   2211   | (array([2]),) |  (array([6]),)  |   1    | (array([4]),)  |     False      |
# |     64     |   2684   | (array([3]),) |  (array([5]),)  |   1    | (array([3]),)  |      True      |
# |     65     |   2482   | (array([4]),) |  (array([1]),)  |   1    | (array([5]),)  |     False      |
# |     66     |   2902   | (array([6]),) |  (array([3]),)  |   1    | (array([6]),)  |      True      |
# |     67     |   2234   | (array([5]),) |  (array([3]),)  |   1    | (array([5]),)  |      True      |
# +------------+----------+---------------+-----------------+--------+----------------+----------------+
# Total cases of neighbor label matches are: 47
# For test set label classification prediction results
# Statistics for dataset: citeseer
# ---------------------------------
# For degree 1 total: 127 (38%) and wrong prediction: 67(52%)
# For degree 2 total: 92 (27%) and wrong prediction: 35(38%)
# For degree 3 total: 45 (13%) and wrong prediction: 14(31%)
# For degree 4 total: 30 (9%) and wrong prediction: 8(26%)
# For degree 5 total: 10 (3%) and wrong prediction: 5(50%)
# For degree 6 total: 5 (1%) and wrong prediction: 2(40%)
# For degree 7 total: 11 (3%) and wrong prediction: 3(27%)
# For degree 9 total: 3 (0%) and wrong prediction: 1(33%)
# For degree 10 total: 2 (0%) and wrong prediction: 1(50%)
# For degree 12 total: 2 (0%) and wrong prediction: 1(50%)

# %%
#Analysis for Citeseer Dataset
dataset = 'blogcatalog'
run_embed(dataset)
# Out:
# /home/sunil/anaconda3/envs/env1/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# file saved
# Embedding dim: 128, graph: blogcatalog
#
# Run number 1:
# Train ratio: 0.9
# micro: 0.40735694822888285
# macro: 0.2638632029510274
# samples: 0.3959302325581396
# weighted: 0.43920250757323276
# Accuracy: 0.3168604651162791
#
# Graph is blogcatalog:
# Graph has 10312 and edges are 333983
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-a15ac64d55b4> in <module>()
#       1 #Analysis for Citeseer Dataset
#       2 dataset = 'blogcatalog'
# ----> 3 run_embed(dataset)
#
# <ipython-input-2-bb9e2e084fb5> in run_embed(dataset_name, save_stats)
#       6     #runnning simple classifier on deepwalk embeddings
#       7     simple_classify_f1(dataset_name,emb,splits_ratio=[0.1],save_stats=True)
# ----> 8     graph_classify_analysis(dataset_name,graph_stat=True)
#
# ~/trial_projects/embeddings/graph_embedding/evaluation/util_func.py in graph_classify_analysis(dataset_name, graph_stat)
#     215                 #n_label_ind = np.where(all_indices==neighbor[0])
#     216                 #print(n_label_ind)
# --> 217                 if np.nonzero(emb_label[i,:])==np.nonzero(labels[int(neighbor[0]),:]):
#     218                     match=True
#     219                     match_counter += 1
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#Analysis for Citeseer Dataset
dataset = 'pubmed'
run_embed(dataset)
# Out:
# file saved
# Embedding dim: 128, graph: pubmed
#
# Run number 1:
# Train ratio: 0.9
# micro: 0.8057809330628803
# macro: 0.7963475542078481
# samples: 0.8057809330628803
# weighted: 0.8066786564389099
# Accuracy: 0.8057809330628803
#
# Graph is pubmed:
# Graph has 19717 and edges are 44327
# +------------+----------+---------------+-----------------+--------+----------------+----------------+
# | Serial No. | Node no. |   True Label  | Predicted Label | Degree | Neighbor label | Neighbor Match |
# +------------+----------+---------------+-----------------+--------+----------------+----------------+
# |     1      |  10833   | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     2      |  12289   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     3      |  19682   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     4      |   9233   | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     5      |   3382   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     6      |  19607   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     7      |  14412   | (array([0]),) |  (array([2]),)  |   1    | (array([1]),)  |     False      |
# |     8      |  15635   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     9      |   4558   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     10     |   8052   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     11     |  11722   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     12     |  13006   | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     13     |  18426   | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |     14     |  16421   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     15     |   5858   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     16     |   7086   | (array([2]),) |  (array([0]),)  |   1    | (array([1]),)  |     False      |
# |     17     |   230    | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     18     |  17084   | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     19     |  17256   | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     20     |   5315   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     21     |   448    | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     22     |   5617   | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     23     |   3367   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     24     |   6459   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |     25     |   6633   | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |     26     |   7544   | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |     27     |  17945   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     28     |   7768   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     29     |   7863   | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     30     |   3585   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     31     |   5339   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     32     |   9074   | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     33     |  17761   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     34     |  18235   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     35     |  11854   | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     36     |  19284   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     37     |  18848   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     38     |  12472   | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     39     |  13899   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     40     |   8416   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |     41     |   8496   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |     42     |  12292   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     43     |  17879   | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     44     |  11726   | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |     45     |  19715   | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     46     |  10870   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     47     |  17567   | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |     48     |  19559   | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     49     |  13040   | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     50     |  15069   | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     51     |  19566   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     52     |  19664   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |     53     |  11295   | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     54     |   2976   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     55     |  19691   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     56     |   9857   | (array([2]),) |  (array([1]),)  |   1    | (array([0]),)  |     False      |
# |     57     |  13547   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     58     |  12044   | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     59     |   6973   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     60     |   5589   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     61     |  10996   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     62     |  14302   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     63     |   3373   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     64     |  16288   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     65     |   4595   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |     66     |  19186   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     67     |  15566   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     68     |  17456   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     69     |  12108   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |     70     |   6080   | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     71     |   7564   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     72     |   7982   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     73     |   7960   | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     74     |  16503   | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     75     |  18569   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |     76     |  14441   | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     77     |  12035   | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     78     |   8524   | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     79     |  16338   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |     80     |   7059   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     81     |   9933   | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     82     |  16693   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     83     |  18915   | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     84     |  19484   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     85     |  13738   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     86     |  19367   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     87     |  17828   | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |     88     |  16490   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     89     |   8878   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     90     |  18885   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     91     |  15728   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     92     |   2285   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |     93     |   8936   | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     94     |  13714   | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |     95     |  14865   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |     96     |  10157   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     97     |  11646   | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     98     |  15336   | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     99     |   8761   | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |    100     |  17027   | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |    101     |  18371   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    102     |   1921   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    103     |   7591   | (array([1]),) |  (array([0]),)  |   1    | (array([2]),)  |     False      |
# |    104     |   7060   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |    105     |   8231   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |    106     |   2956   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    107     |  11265   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    108     |  18171   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    109     |   2455   | (array([0]),) |  (array([1]),)  |   1    | (array([2]),)  |     False      |
# |    110     |  19533   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |    111     |  13493   | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |    112     |  11081   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    113     |  19326   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    114     |  13130   | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |    115     |  15445   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |    116     |  17376   | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |    117     |   8439   | (array([0]),) |  (array([1]),)  |   1    | (array([2]),)  |     False      |
# |    118     |   8013   | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |    119     |   5726   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |    120     |   8979   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    121     |  13194   | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |    122     |   693    | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    123     |  12283   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |    124     |   6128   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |    125     |  10333   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    126     |   1460   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    127     |   8676   | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |    128     |   5453   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    129     |  11428   | (array([2]),) |  (array([0]),)  |   1    | (array([1]),)  |     False      |
# |    130     |   2607   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |    131     |  12703   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |    132     |  13524   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    133     |  16920   | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |    134     |  11792   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    135     |   5527   | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |    136     |  12591   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    137     |   8949   | (array([1]),) |  (array([0]),)  |   1    | (array([1]),)  |      True      |
# |    138     |  15485   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    139     |  11290   | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |    140     |   9492   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |    141     |  19332   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    142     |  19036   | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |    143     |  10906   | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |    144     |   2398   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    145     |  17321   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    146     |  10685   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    147     |  12775   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    148     |  11360   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    149     |  11827   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    150     |  14983   | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |    151     |   1805   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    152     |  14615   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |    153     |  13977   | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |    154     |   7325   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    155     |   7395   | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |    156     |  12006   | (array([2]),) |  (array([1]),)  |   1    | (array([0]),)  |     False      |
# |    157     |   5625   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    158     |   7519   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |    159     |   5881   | (array([2]),) |  (array([0]),)  |   1    | (array([1]),)  |     False      |
# |    160     |  19211   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    161     |   760    | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    162     |  14133   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    163     |  15163   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    164     |   437    | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |    165     |   8187   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    166     |  17109   | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |    167     |  17883   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |    168     |  19229   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    169     |   4693   | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |    170     |  18796   | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |    171     |   5495   | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |    172     |   9918   | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |    173     |  18469   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    174     |  19516   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    175     |   5466   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    176     |  19631   | (array([2]),) |  (array([0]),)  |   1    | (array([1]),)  |     False      |
# |    177     |   331    | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    178     |   4769   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    179     |  10701   | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |    180     |  16991   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    181     |  17225   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    182     |  18759   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    183     |  13294   | (array([1]),) |  (array([2]),)  |   1    | (array([0]),)  |     False      |
# |    184     |   1985   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    185     |  11427   | (array([0]),) |  (array([1]),)  |   1    | (array([2]),)  |     False      |
# |    186     |  18974   | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |    187     |   1670   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    188     |   1180   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    189     |  14199   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |    190     |  12221   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    191     |  12847   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    192     |   7575   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    193     |   7364   | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |    194     |   4211   | (array([1]),) |  (array([0]),)  |   1    | (array([2]),)  |     False      |
# |    195     |   565    | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    196     |   557    | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |    197     |  19319   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    198     |  16875   | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |    199     |   7618   | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |    200     |  10346   | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |    201     |  10124   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    202     |  19419   | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |    203     |   7642   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |    204     |  12411   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    205     |   1648   | (array([1]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |    206     |   5044   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    207     |  12984   | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |    208     |  19415   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    209     |  19458   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    210     |  17840   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |    211     |  19627   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    212     |  19501   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    213     |  14665   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    214     |  17180   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    215     |   8171   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |    216     |  15387   | (array([0]),) |  (array([1]),)  |   1    | (array([0]),)  |      True      |
# |    217     |  18153   | (array([2]),) |  (array([1]),)  |   1    | (array([2]),)  |      True      |
# |    218     |   2814   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    219     |   9376   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    220     |   2436   | (array([0]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    221     |   5957   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# |    222     |  17433   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    223     |  19220   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    224     |  10978   | (array([1]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    225     |  11994   | (array([0]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |    226     |   6542   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    227     |  13237   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |    228     |   8706   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    229     |  17719   | (array([2]),) |  (array([1]),)  |   1    | (array([1]),)  |     False      |
# |    230     |  13206   | (array([0]),) |  (array([2]),)  |   1    | (array([0]),)  |      True      |
# +------------+----------+---------------+-----------------+--------+----------------+----------------+
# Total cases of neighbor label matches are: 83
# For test set label classification prediction results
# Statistics for dataset: pubmed
# ---------------------------------
# For degree 1 total: 914 (46%) and wrong prediction: 230(25%)
# For degree 2 total: 324 (16%) and wrong prediction: 55(16%)
# For degree 3 total: 170 (8%) and wrong prediction: 21(12%)
# For degree 4 total: 79 (4%) and wrong prediction: 10(12%)
# For degree 5 total: 62 (3%) and wrong prediction: 5(8%)
# For degree 6 total: 38 (1%) and wrong prediction: 3(7%)
# For degree 7 total: 50 (2%) and wrong prediction: 4(8%)
# For degree 8 total: 33 (1%) and wrong prediction: 5(15%)
# For degree 9 total: 16 (0%) and wrong prediction: 5(31%)
# For degree 11 total: 22 (1%) and wrong prediction: 4(18%)
# For degree 12 total: 26 (1%) and wrong prediction: 2(7%)
# For degree 13 total: 19 (0%) and wrong prediction: 3(15%)
# For degree 14 total: 19 (0%) and wrong prediction: 4(21%)
# For degree 15 total: 16 (0%) and wrong prediction: 5(31%)
# For degree 16 total: 15 (0%) and wrong prediction: 4(26%)
# For degree 17 total: 17 (0%) and wrong prediction: 3(17%)
# For degree 18 total: 10 (0%) and wrong prediction: 1(10%)
# For degree 19 total: 14 (0%) and wrong prediction: 4(28%)
# For degree 20 total: 12 (0%) and wrong prediction: 4(33%)
# For degree 21 total: 6 (0%) and wrong prediction: 3(50%)
# For degree 23 total: 7 (0%) and wrong prediction: 2(28%)
# For degree 26 total: 5 (0%) and wrong prediction: 2(40%)
# For degree 28 total: 6 (0%) and wrong prediction: 1(16%)
# For degree 38 total: 2 (0%) and wrong prediction: 1(50%)
# For degree 40 total: 2 (0%) and wrong prediction: 1(50%)
# For degree 46 total: 1 (0%) and wrong prediction: 1(100%)

# %%
#Analysis for Citeseer Dataset
dataset = 'cora'
run_embed(dataset)
# Out:
# file saved
# Embedding dim: 128, graph: cora
#
# Run number 1:
# Train ratio: 0.9
# micro: 0.8376383763837638
# macro: 0.8230022432436838
# samples: 0.8376383763837638
# weighted: 0.8347950399963107
# Accuracy: 0.8376383763837638
#
# Graph is cora:
# Graph has 2708 and edges are 5278
# +------------+----------+---------------+-----------------+--------+----------------+----------------+
# | Serial No. | Node no. |   True Label  | Predicted Label | Degree | Neighbor label | Neighbor Match |
# +------------+----------+---------------+-----------------+--------+----------------+----------------+
# |     1      |   923    | (array([0]),) |  (array([3]),)  |   1    | (array([3]),)  |     False      |
# |     2      |   2041   | (array([2]),) |  (array([5]),)  |   1    | (array([2]),)  |      True      |
# |     3      |   2551   | (array([3]),) |  (array([2]),)  |   1    | (array([2]),)  |     False      |
# |     4      |   1648   | (array([2]),) |  (array([6]),)  |   1    | (array([6]),)  |     False      |
# |     5      |   2585   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     6      |   2640   | (array([3]),) |  (array([2]),)  |   1    | (array([3]),)  |      True      |
# |     7      |   1677   | (array([2]),) |  (array([0]),)  |   1    | (array([2]),)  |      True      |
# |     8      |   2319   | (array([2]),) |  (array([5]),)  |   1    | (array([2]),)  |      True      |
# |     9      |   1912   | (array([1]),) |  (array([2]),)  |   1    | (array([1]),)  |      True      |
# |     10     |   2273   | (array([2]),) |  (array([0]),)  |   1    | (array([0]),)  |     False      |
# |     11     |   2073   | (array([6]),) |  (array([2]),)  |   1    | (array([6]),)  |      True      |
# |     12     |   317    | (array([0]),) |  (array([3]),)  |   1    | (array([0]),)  |      True      |
# +------------+----------+---------------+-----------------+--------+----------------+----------------+
# Total cases of neighbor label matches are: 8
# For test set label classification prediction results
# Statistics for dataset: cora
# ---------------------------------
# For degree 1 total: 55 (20%) and wrong prediction: 12(21%)
# For degree 2 total: 55 (20%) and wrong prediction: 12(21%)
# For degree 3 total: 62 (22%) and wrong prediction: 11(17%)
# For degree 4 total: 37 (13%) and wrong prediction: 2(5%)
# For degree 5 total: 33 (12%) and wrong prediction: 3(9%)
# For degree 6 total: 10 (3%) and wrong prediction: 2(20%)
# For degree 7 total: 8 (2%) and wrong prediction: 2(25%)

# %%
#Analysis for Citeseer Dataset
dataset = 'reddit'
run_embed(dataset)
# Out:
# file saved
# Embedding dim: 128, graph: reddit
#
# Run number 1:
# Train ratio: 0.9
# micro: 0.8975404558526849
# macro: 0.8701530715543039
# samples: 0.8975404558526849
# weighted: 0.8904164275589822
# Accuracy: 0.8975404558526849
#
# Graph is reddit:
# Graph has 231443 and edges are 11606919
# +------------+----------+-----------------------------------------------------+-----------------+--------+-----------------------------------------------------+----------------+
# | Serial No. | Node no. |                      True Label                     | Predicted Label | Degree |                    Neighbor label                   | Neighbor Match |
# +------------+----------+-----------------------------------------------------+-----------------+--------+-----------------------------------------------------+----------------+
# |     1      |  171174  |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    | (array([0], dtype=int32), array([30], dtype=int32)) |     False      |
# |     2      |  218554  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([40], dtype=int32)) |     False      |
# |     3      |  88752   | (array([0], dtype=int32), array([14], dtype=int32)) |  (array([14]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |     4      |  181328  | (array([0], dtype=int32), array([38], dtype=int32)) |  (array([38]),) |   1    | (array([0], dtype=int32), array([34], dtype=int32)) |     False      |
# |     5      |  18970   | (array([0], dtype=int32), array([40], dtype=int32)) |  (array([40]),) |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |     6      |  185006  | (array([0], dtype=int32), array([22], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([23], dtype=int32)) |     False      |
# |     7      |  132426  |  (array([0], dtype=int32), array([1], dtype=int32)) |  (array([1]),)  |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |     8      |  70763   | (array([0], dtype=int32), array([35], dtype=int32)) |  (array([35]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |     9      |  92334   | (array([0], dtype=int32), array([14], dtype=int32)) |  (array([14]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |     10     |  66198   | (array([0], dtype=int32), array([22], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |     11     |  117826  |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |     12     |  81573   | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |     13     |  87581   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |     14     |  194329  | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |     15     |  18326   |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([0]),)  |   1    |  (array([0], dtype=int32), array([2], dtype=int32)) |     False      |
# |     16     |  40832   |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([31], dtype=int32)) |     False      |
# |     17     |  221166  |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([28], dtype=int32)) |     False      |
# |     18     |   593    | (array([0], dtype=int32), array([39], dtype=int32)) |  (array([39]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |     19     |  69769   | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    | (array([0], dtype=int32), array([33], dtype=int32)) |     False      |
# |     20     |  24673   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([10], dtype=int32)) |     False      |
# |     21     |  172472  |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([0]),)  |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |     22     |  25119   |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |     23     |  60597   | (array([0], dtype=int32), array([32], dtype=int32)) |  (array([32]),) |   1    | (array([0], dtype=int32), array([40], dtype=int32)) |     False      |
# |     24     |  131108  |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([0]),)  |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |     25     |  216677  | (array([0], dtype=int32), array([37], dtype=int32)) |  (array([15]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |     26     |  40370   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |     27     |  87106   | (array([0], dtype=int32), array([35], dtype=int32)) |  (array([35]),) |   1    | (array([0], dtype=int32), array([10], dtype=int32)) |     False      |
# |     28     |   7887   | (array([0], dtype=int32), array([30], dtype=int32)) |  (array([30]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |     29     |  162554  | (array([0], dtype=int32), array([22], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([31], dtype=int32)) |     False      |
# |     30     |  177650  |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([0]),)  |   1    | (array([0], dtype=int32), array([19], dtype=int32)) |     False      |
# |     31     |  101044  | (array([0], dtype=int32), array([10], dtype=int32)) |  (array([10]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |     32     |  228712  |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |     33     |  209791  | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    | (array([0], dtype=int32), array([18], dtype=int32)) |      True      |
# |     34     |  21923   | (array([0], dtype=int32), array([14], dtype=int32)) |  (array([14]),) |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |     35     |  149941  | (array([0], dtype=int32), array([27], dtype=int32)) |  (array([22]),) |   1    |  (array([0], dtype=int32), array([6], dtype=int32)) |     False      |
# |     36     |  56781   | (array([0], dtype=int32), array([12], dtype=int32)) |  (array([12]),) |   1    | (array([0], dtype=int32), array([21], dtype=int32)) |     False      |
# |     37     |  220431  |  (array([0], dtype=int32), array([2], dtype=int32)) |  (array([2]),)  |   1    | (array([0], dtype=int32), array([27], dtype=int32)) |     False      |
# |     38     |  183046  | (array([0], dtype=int32), array([38], dtype=int32)) |  (array([38]),) |   1    | (array([0], dtype=int32), array([31], dtype=int32)) |     False      |
# |     39     |  62267   | (array([0], dtype=int32), array([14], dtype=int32)) |  (array([14]),) |   1    |  (array([0], dtype=int32), array([7], dtype=int32)) |     False      |
# |     40     |  192390  | (array([0], dtype=int32), array([40], dtype=int32)) |  (array([40]),) |   1    | (array([0], dtype=int32), array([28], dtype=int32)) |     False      |
# |     41     |  103884  | (array([0], dtype=int32), array([10], dtype=int32)) |  (array([10]),) |   1    | (array([0], dtype=int32), array([37], dtype=int32)) |     False      |
# |     42     |  17771   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([21], dtype=int32)) |     False      |
# |     43     |  153638  |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |      True      |
# |     44     |  163536  | (array([0], dtype=int32), array([27], dtype=int32)) |  (array([27]),) |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |     False      |
# |     45     |   4645   |  (array([0], dtype=int32), array([4], dtype=int32)) |  (array([4]),)  |   1    | (array([0], dtype=int32), array([26], dtype=int32)) |     False      |
# |     46     |  154343  |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |     47     |  15173   | (array([0], dtype=int32), array([10], dtype=int32)) |  (array([10]),) |   1    | (array([0], dtype=int32), array([36], dtype=int32)) |     False      |
# |     48     |  93152   | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([23], dtype=int32)) |      True      |
# |     49     |  130095  |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |     50     |  39676   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([23], dtype=int32)) |     False      |
# |     51     |  213546  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([14], dtype=int32)) |     False      |
# |     52     |  184097  | (array([0], dtype=int32), array([28], dtype=int32)) |  (array([28]),) |   1    | (array([0], dtype=int32), array([39], dtype=int32)) |     False      |
# |     53     |  91773   |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([0]),)  |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |     54     |  205501  | (array([0], dtype=int32), array([27], dtype=int32)) |  (array([27]),) |   1    | (array([0], dtype=int32), array([21], dtype=int32)) |     False      |
# |     55     |  105155  | (array([0], dtype=int32), array([19], dtype=int32)) |  (array([19]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |     56     |  84132   | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([19], dtype=int32)) |     False      |
# |     57     |  72671   |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([18], dtype=int32)) |     False      |
# |     58     |  36902   | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    | (array([0], dtype=int32), array([18], dtype=int32)) |      True      |
# |     59     |  189865  | (array([0], dtype=int32), array([20], dtype=int32)) |  (array([20]),) |   1    | (array([0], dtype=int32), array([35], dtype=int32)) |     False      |
# |     60     |  11706   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |     61     |  65140   | (array([0], dtype=int32), array([19], dtype=int32)) |  (array([19]),) |   1    | (array([0], dtype=int32), array([33], dtype=int32)) |     False      |
# |     62     |  222623  | (array([0], dtype=int32), array([37], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([18], dtype=int32)) |     False      |
# |     63     |  53334   | (array([0], dtype=int32), array([10], dtype=int32)) |  (array([10]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |     64     |  28340   |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([0]),)  |   1    | (array([0], dtype=int32), array([18], dtype=int32)) |     False      |
# |     65     |  163814  | (array([0], dtype=int32), array([31], dtype=int32)) |  (array([31]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |     66     |  106080  |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([22]),) |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |     67     |  96964   | (array([0], dtype=int32), array([35], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([31], dtype=int32)) |     False      |
# |     68     |   6297   |  (array([0], dtype=int32), array([4], dtype=int32)) |  (array([4]),)  |   1    |  (array([0], dtype=int32), array([4], dtype=int32)) |      True      |
# |     69     |   9178   | (array([0], dtype=int32), array([12], dtype=int32)) |  (array([12]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |     70     |  144574  |  (array([0], dtype=int32), array([4], dtype=int32)) |  (array([4]),)  |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |     71     |  183532  | (array([0], dtype=int32), array([40], dtype=int32)) |  (array([40]),) |   1    | (array([0], dtype=int32), array([31], dtype=int32)) |     False      |
# |     72     |  28020   | (array([0], dtype=int32), array([36], dtype=int32)) |  (array([36]),) |   1    |  (array([0], dtype=int32), array([4], dtype=int32)) |     False      |
# |     73     |  224208  | (array([0], dtype=int32), array([22], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |      True      |
# |     74     |  139078  | (array([0], dtype=int32), array([38], dtype=int32)) |  (array([38]),) |   1    | (array([0], dtype=int32), array([29], dtype=int32)) |     False      |
# |     75     |  220384  | (array([0], dtype=int32), array([34], dtype=int32)) |  (array([34]),) |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |     False      |
# |     76     |  68635   | (array([0], dtype=int32), array([17], dtype=int32)) |  (array([17]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |     77     |  199745  | (array([0], dtype=int32), array([10], dtype=int32)) |  (array([10]),) |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |     False      |
# |     78     |  95134   | (array([0], dtype=int32), array([32], dtype=int32)) |  (array([32]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |     79     |  110776  | (array([0], dtype=int32), array([26], dtype=int32)) |  (array([26]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |     80     |  212033  | (array([0], dtype=int32), array([34], dtype=int32)) |  (array([34]),) |   1    | (array([0], dtype=int32), array([18], dtype=int32)) |     False      |
# |     81     |  156668  | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |     82     |  42942   | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([23], dtype=int32)) |      True      |
# |     83     |  93003   | (array([0], dtype=int32), array([17], dtype=int32)) |  (array([17]),) |   1    | (array([0], dtype=int32), array([30], dtype=int32)) |     False      |
# |     84     |  57248   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([33], dtype=int32)) |     False      |
# |     85     |  181055  | (array([0], dtype=int32), array([33], dtype=int32)) |  (array([14]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |     86     |  32347   |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    |  (array([0], dtype=int32), array([4], dtype=int32)) |     False      |
# |     87     |  15265   | (array([0], dtype=int32), array([20], dtype=int32)) |  (array([20]),) |   1    | (array([0], dtype=int32), array([30], dtype=int32)) |     False      |
# |     88     |  230216  | (array([0], dtype=int32), array([27], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |     89     |  151954  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([23], dtype=int32)) |     False      |
# |     90     |  18091   | (array([0], dtype=int32), array([29], dtype=int32)) |  (array([29]),) |   1    | (array([0], dtype=int32), array([30], dtype=int32)) |     False      |
# |     91     |  202160  | (array([0], dtype=int32), array([27], dtype=int32)) |  (array([27]),) |   1    | (array([0], dtype=int32), array([25], dtype=int32)) |     False      |
# |     92     |  26067   | (array([0], dtype=int32), array([14], dtype=int32)) |  (array([22]),) |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |     93     |   540    | (array([0], dtype=int32), array([19], dtype=int32)) |  (array([19]),) |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |     False      |
# |     94     |  23412   | (array([0], dtype=int32), array([40], dtype=int32)) |  (array([40]),) |   1    | (array([0], dtype=int32), array([26], dtype=int32)) |     False      |
# |     95     |  160165  | (array([0], dtype=int32), array([22], dtype=int32)) |  (array([22]),) |   1    |  (array([0], dtype=int32), array([6], dtype=int32)) |     False      |
# |     96     |  77588   | (array([0], dtype=int32), array([34], dtype=int32)) |  (array([34]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |     97     |  60779   | (array([0], dtype=int32), array([30], dtype=int32)) |  (array([30]),) |   1    | (array([0], dtype=int32), array([30], dtype=int32)) |      True      |
# |     98     |  148395  | (array([0], dtype=int32), array([31], dtype=int32)) |  (array([31]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |     99     |  128344  | (array([0], dtype=int32), array([36], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    100     |  156156  | (array([0], dtype=int32), array([19], dtype=int32)) |  (array([19]),) |   1    | (array([0], dtype=int32), array([14], dtype=int32)) |     False      |
# |    101     |  176057  | (array([0], dtype=int32), array([22], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([19], dtype=int32)) |     False      |
# |    102     |  127686  |  (array([0], dtype=int32), array([2], dtype=int32)) |  (array([2]),)  |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |    103     |  202623  |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    |  (array([0], dtype=int32), array([6], dtype=int32)) |     False      |
# |    104     |   267    | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    105     |  139873  |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    | (array([0], dtype=int32), array([30], dtype=int32)) |     False      |
# |    106     |   8647   |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    | (array([0], dtype=int32), array([30], dtype=int32)) |     False      |
# |    107     |  178402  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([21], dtype=int32)) |     False      |
# |    108     |  178150  | (array([0], dtype=int32), array([38], dtype=int32)) |  (array([38]),) |   1    | (array([0], dtype=int32), array([19], dtype=int32)) |     False      |
# |    109     |  35116   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([36], dtype=int32)) |     False      |
# |    110     |  126765  |  (array([0], dtype=int32), array([9], dtype=int32)) |  (array([9]),)  |   1    | (array([0], dtype=int32), array([30], dtype=int32)) |     False      |
# |    111     |  88919   | (array([0], dtype=int32), array([34], dtype=int32)) |  (array([34]),) |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |    112     |  127301  | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    | (array([0], dtype=int32), array([35], dtype=int32)) |     False      |
# |    113     |  68728   | (array([0], dtype=int32), array([14], dtype=int32)) |  (array([14]),) |   1    | (array([0], dtype=int32), array([14], dtype=int32)) |      True      |
# |    114     |  125558  | (array([0], dtype=int32), array([38], dtype=int32)) |  (array([38]),) |   1    |  (array([0], dtype=int32), array([7], dtype=int32)) |     False      |
# |    115     |  30498   | (array([0], dtype=int32), array([35], dtype=int32)) |  (array([35]),) |   1    | (array([0], dtype=int32), array([19], dtype=int32)) |     False      |
# |    116     |  39349   |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([22]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |    117     |  210621  |  (array([0], dtype=int32), array([4], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    118     |  192995  | (array([0], dtype=int32), array([40], dtype=int32)) |  (array([40]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    119     |  160173  |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    | (array([0], dtype=int32), array([31], dtype=int32)) |     False      |
# |    120     |  77505   |  (array([0], dtype=int32), array([5], dtype=int32)) |  (array([5]),)  |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |    121     |  188516  | (array([0], dtype=int32), array([27], dtype=int32)) |  (array([27]),) |   1    | (array([0], dtype=int32), array([27], dtype=int32)) |      True      |
# |    122     |  201390  | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |    123     |  49053   | (array([0], dtype=int32), array([28], dtype=int32)) |  (array([28]),) |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |     False      |
# |    124     |  225497  |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([0]),)  |   1    | (array([0], dtype=int32), array([29], dtype=int32)) |     False      |
# |    125     |  168039  | (array([0], dtype=int32), array([27], dtype=int32)) |  (array([27]),) |   1    |  (array([0], dtype=int32), array([2], dtype=int32)) |     False      |
# |    126     |  181943  | (array([0], dtype=int32), array([13], dtype=int32)) |  (array([22]),) |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |     False      |
# |    127     |  72989   |  (array([0], dtype=int32), array([2], dtype=int32)) |  (array([2]),)  |   1    |  (array([0], dtype=int32), array([6], dtype=int32)) |     False      |
# |    128     |  143667  | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    129     |  184431  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([23], dtype=int32)) |     False      |
# |    130     |  191667  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    |  (array([0], dtype=int32), array([5], dtype=int32)) |     False      |
# |    131     |  89439   |  (array([0], dtype=int32), array([2], dtype=int32)) |  (array([2]),)  |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    132     |  169930  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |      True      |
# |    133     |  131776  | (array([0], dtype=int32), array([10], dtype=int32)) |  (array([2]),)  |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    134     |  45106   |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([30], dtype=int32)) |     False      |
# |    135     |  131702  | (array([0], dtype=int32), array([32], dtype=int32)) |  (array([22]),) |   1    |  (array([0], dtype=int32), array([2], dtype=int32)) |     False      |
# |    136     |  194418  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |    137     |   2287   | (array([0], dtype=int32), array([29], dtype=int32)) |  (array([18]),) |   1    | (array([0], dtype=int32), array([19], dtype=int32)) |     False      |
# |    138     |  199434  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([39], dtype=int32)) |     False      |
# |    139     |  30186   | (array([0], dtype=int32), array([28], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([27], dtype=int32)) |     False      |
# |    140     |  74409   | (array([0], dtype=int32), array([27], dtype=int32)) |  (array([27]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |    141     |  126987  |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    | (array([0], dtype=int32), array([23], dtype=int32)) |     False      |
# |    142     |  34509   | (array([0], dtype=int32), array([27], dtype=int32)) |  (array([27]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    143     |  171984  | (array([0], dtype=int32), array([31], dtype=int32)) |  (array([31]),) |   1    | (array([0], dtype=int32), array([19], dtype=int32)) |     False      |
# |    144     |  102365  | (array([0], dtype=int32), array([22], dtype=int32)) |  (array([37]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |      True      |
# |    145     |  44397   | (array([0], dtype=int32), array([39], dtype=int32)) |  (array([39]),) |   1    | (array([0], dtype=int32), array([35], dtype=int32)) |     False      |
# |    146     |  36241   | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    |  (array([0], dtype=int32), array([4], dtype=int32)) |     False      |
# |    147     |  196422  | (array([0], dtype=int32), array([34], dtype=int32)) |  (array([34]),) |   1    | (array([0], dtype=int32), array([10], dtype=int32)) |     False      |
# |    148     |  50981   | (array([0], dtype=int32), array([26], dtype=int32)) |  (array([26]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |    149     |  131555  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |    150     |  193888  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([10], dtype=int32)) |     False      |
# |    151     |   3772   | (array([0], dtype=int32), array([31], dtype=int32)) |  (array([31]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    152     |  24179   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([14], dtype=int32)) |     False      |
# |    153     |  200169  | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([14], dtype=int32)) |     False      |
# |    154     |  166837  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |    155     |  137500  | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |    156     |  33837   | (array([0], dtype=int32), array([12], dtype=int32)) |  (array([12]),) |   1    | (array([0], dtype=int32), array([33], dtype=int32)) |     False      |
# |    157     |  187748  | (array([0], dtype=int32), array([39], dtype=int32)) |  (array([39]),) |   1    | (array([0], dtype=int32), array([26], dtype=int32)) |     False      |
# |    158     |  125378  | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    159     |  84001   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([37], dtype=int32)) |     False      |
# |    160     |  228312  | (array([0], dtype=int32), array([21], dtype=int32)) |  (array([21]),) |   1    | (array([0], dtype=int32), array([18], dtype=int32)) |     False      |
# |    161     |  155591  |  (array([0], dtype=int32), array([4], dtype=int32)) |  (array([4]),)  |   1    | (array([0], dtype=int32), array([36], dtype=int32)) |     False      |
# |    162     |  44250   | (array([0], dtype=int32), array([35], dtype=int32)) |  (array([35]),) |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |    163     |  161568  | (array([0], dtype=int32), array([29], dtype=int32)) |  (array([29]),) |   1    |  (array([0], dtype=int32), array([6], dtype=int32)) |     False      |
# |    164     |  77386   | (array([0], dtype=int32), array([22], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([14], dtype=int32)) |     False      |
# |    165     |  78516   | (array([0], dtype=int32), array([28], dtype=int32)) |  (array([28]),) |   1    | (array([0], dtype=int32), array([10], dtype=int32)) |     False      |
# |    166     |  43517   |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |    167     |  55604   | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([25], dtype=int32)) |     False      |
# |    168     |  171876  |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([0]),)  |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    169     |  188080  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([23], dtype=int32)) |     False      |
# |    170     |  38161   | (array([0], dtype=int32), array([28], dtype=int32)) |  (array([28]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |    171     |  93087   |  (array([0], dtype=int32), array([4], dtype=int32)) |  (array([27]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    172     |  179930  | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([21], dtype=int32)) |     False      |
# |    173     |  112452  | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([27], dtype=int32)) |     False      |
# |    174     |  76939   |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([31], dtype=int32)) |     False      |
# |    175     |  139059  |  (array([0], dtype=int32), array([7], dtype=int32)) |  (array([7]),)  |   1    | (array([0], dtype=int32), array([13], dtype=int32)) |     False      |
# |    176     |  93619   |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([0]),)  |   1    | (array([0], dtype=int32), array([14], dtype=int32)) |     False      |
# |    177     |  59353   | (array([0], dtype=int32), array([11], dtype=int32)) |  (array([11]),) |   1    | (array([0], dtype=int32), array([19], dtype=int32)) |     False      |
# |    178     |  92652   |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |    179     |  67001   | (array([0], dtype=int32), array([29], dtype=int32)) |  (array([29]),) |   1    | (array([0], dtype=int32), array([33], dtype=int32)) |     False      |
# |    180     |  183385  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([10], dtype=int32)) |     False      |
# |    181     |  42095   | (array([0], dtype=int32), array([35], dtype=int32)) |  (array([35]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    182     |  164530  |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    183     |  171891  | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([10], dtype=int32)) |     False      |
# |    184     |  34684   | (array([0], dtype=int32), array([10], dtype=int32)) |  (array([10]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    185     |  198313  | (array([0], dtype=int32), array([28], dtype=int32)) |  (array([28]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    186     |  190612  | (array([0], dtype=int32), array([32], dtype=int32)) |  (array([13]),) |   1    | (array([0], dtype=int32), array([33], dtype=int32)) |     False      |
# |    187     |  39632   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([21], dtype=int32)) |     False      |
# |    188     |  210027  | (array([0], dtype=int32), array([33], dtype=int32)) |  (array([33]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |    189     |  62446   | (array([0], dtype=int32), array([33], dtype=int32)) |  (array([33]),) |   1    | (array([0], dtype=int32), array([23], dtype=int32)) |     False      |
# |    190     |  162408  | (array([0], dtype=int32), array([19], dtype=int32)) |  (array([27]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    191     |  75956   | (array([0], dtype=int32), array([35], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([14], dtype=int32)) |     False      |
# |    192     |  25335   | (array([0], dtype=int32), array([38], dtype=int32)) |  (array([38]),) |   1    |  (array([0], dtype=int32), array([2], dtype=int32)) |     False      |
# |    193     |  71405   |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([0]),)  |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    194     |  120055  | (array([0], dtype=int32), array([27], dtype=int32)) |  (array([27]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    195     |  108974  |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    196     |  33889   | (array([0], dtype=int32), array([36], dtype=int32)) |  (array([36]),) |   1    | (array([0], dtype=int32), array([18], dtype=int32)) |     False      |
# |    197     |  63036   |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([0]),)  |   1    | (array([0], dtype=int32), array([40], dtype=int32)) |     False      |
# |    198     |  54038   | (array([0], dtype=int32), array([14], dtype=int32)) |  (array([14]),) |   1    | (array([0], dtype=int32), array([17], dtype=int32)) |     False      |
# |    199     |   3738   | (array([0], dtype=int32), array([27], dtype=int32)) |  (array([27]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |    200     |  80805   |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([19], dtype=int32)) |     False      |
# |    201     |  214516  | (array([0], dtype=int32), array([21], dtype=int32)) |  (array([21]),) |   1    | (array([0], dtype=int32), array([11], dtype=int32)) |     False      |
# |    202     |  74584   | (array([0], dtype=int32), array([26], dtype=int32)) |  (array([26]),) |   1    | (array([0], dtype=int32), array([23], dtype=int32)) |     False      |
# |    203     |  212041  | (array([0], dtype=int32), array([19], dtype=int32)) |  (array([19]),) |   1    | (array([0], dtype=int32), array([16], dtype=int32)) |     False      |
# |    204     |  88156   | (array([0], dtype=int32), array([33], dtype=int32)) |  (array([33]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    205     |  176598  | (array([0], dtype=int32), array([38], dtype=int32)) |  (array([38]),) |   1    | (array([0], dtype=int32), array([18], dtype=int32)) |     False      |
# |    206     |  131058  |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([23], dtype=int32)) |     False      |
# |    207     |  221047  | (array([0], dtype=int32), array([29], dtype=int32)) |  (array([29]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    208     |  195126  | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    | (array([0], dtype=int32), array([30], dtype=int32)) |     False      |
# |    209     |   5595   | (array([0], dtype=int32), array([36], dtype=int32)) |  (array([36]),) |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |     False      |
# |    210     |  207486  | (array([0], dtype=int32), array([38], dtype=int32)) |  (array([38]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    211     |  213476  | (array([0], dtype=int32), array([28], dtype=int32)) |  (array([3]),)  |   1    |  (array([0], dtype=int32), array([9], dtype=int32)) |     False      |
# |    212     |  76903   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |      True      |
# |    213     |   3004   | (array([0], dtype=int32), array([33], dtype=int32)) |  (array([33]),) |   1    | (array([0], dtype=int32), array([31], dtype=int32)) |     False      |
# |    214     |   2708   | (array([0], dtype=int32), array([37], dtype=int32)) |  (array([37]),) |   1    | (array([0], dtype=int32), array([28], dtype=int32)) |     False      |
# |    215     |  133475  | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([17], dtype=int32)) |     False      |
# |    216     |  183116  |  (array([0], dtype=int32), array([1], dtype=int32)) |  (array([1]),)  |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    217     |  177936  | (array([0], dtype=int32), array([40], dtype=int32)) |  (array([40]),) |   1    | (array([0], dtype=int32), array([28], dtype=int32)) |     False      |
# |    218     |  26320   |  (array([0], dtype=int32), array([5], dtype=int32)) |  (array([5]),)  |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |     False      |
# |    219     |  48757   | (array([0], dtype=int32), array([31], dtype=int32)) |  (array([31]),) |   1    | (array([0], dtype=int32), array([29], dtype=int32)) |     False      |
# |    220     |  224531  | (array([0], dtype=int32), array([28], dtype=int32)) |  (array([28]),) |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |     False      |
# |    221     |  203805  | (array([0], dtype=int32), array([31], dtype=int32)) |  (array([31]),) |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |    222     |  43778   | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    | (array([0], dtype=int32), array([30], dtype=int32)) |     False      |
# |    223     |  226394  | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |    224     |  26639   | (array([0], dtype=int32), array([40], dtype=int32)) |  (array([40]),) |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |     False      |
# |    225     |  230318  | (array([0], dtype=int32), array([38], dtype=int32)) |  (array([38]),) |   1    | (array([0], dtype=int32), array([37], dtype=int32)) |     False      |
# |    226     |  223508  | (array([0], dtype=int32), array([36], dtype=int32)) |  (array([15]),) |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |     False      |
# |    227     |  74595   | (array([0], dtype=int32), array([21], dtype=int32)) |  (array([21]),) |   1    | (array([0], dtype=int32), array([39], dtype=int32)) |     False      |
# |    228     |  14989   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    |  (array([0], dtype=int32), array([1], dtype=int32)) |     False      |
# |    229     |  203294  | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |    230     |  13214   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([25], dtype=int32)) |     False      |
# |    231     |  210717  |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |    232     |  182125  | (array([0], dtype=int32), array([19], dtype=int32)) |  (array([19]),) |   1    | (array([0], dtype=int32), array([11], dtype=int32)) |     False      |
# |    233     |  98317   | (array([0], dtype=int32), array([37], dtype=int32)) |  (array([8]),)  |   1    | (array([0], dtype=int32), array([21], dtype=int32)) |     False      |
# |    234     |  193270  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([18], dtype=int32)) |     False      |
# |    235     |  215422  | (array([0], dtype=int32), array([36], dtype=int32)) |  (array([36]),) |   1    | (array([0], dtype=int32), array([10], dtype=int32)) |     False      |
# |    236     |  24873   |  (array([0], dtype=int32), array([2], dtype=int32)) |  (array([2]),)  |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |    237     |  99927   |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    238     |  55194   |  (array([0], dtype=int32), array([5], dtype=int32)) |  (array([5]),)  |   1    | (array([0], dtype=int32), array([36], dtype=int32)) |     False      |
# |    239     |  39939   | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    | (array([0], dtype=int32), array([19], dtype=int32)) |     False      |
# |    240     |  94970   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([39], dtype=int32)) |     False      |
# |    241     |  221583  |  (array([0], dtype=int32), array([5], dtype=int32)) |  (array([5]),)  |   1    | (array([0], dtype=int32), array([19], dtype=int32)) |     False      |
# |    242     |  41650   | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    |  (array([0], dtype=int32), array([5], dtype=int32)) |     False      |
# |    243     |  231316  | (array([0], dtype=int32), array([28], dtype=int32)) |  (array([28]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    244     |  71854   |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    | (array([0], dtype=int32), array([27], dtype=int32)) |     False      |
# |    245     |  156766  | (array([0], dtype=int32), array([13], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([40], dtype=int32)) |     False      |
# |    246     |  131482  | (array([0], dtype=int32), array([38], dtype=int32)) |  (array([38]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    247     |  137729  | (array([0], dtype=int32), array([29], dtype=int32)) |  (array([29]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    248     |  213784  |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |    249     |  112402  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([11], dtype=int32)) |     False      |
# |    250     |  84962   | (array([0], dtype=int32), array([28], dtype=int32)) |  (array([28]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    251     |  60075   | (array([0], dtype=int32), array([19], dtype=int32)) |  (array([19]),) |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |     False      |
# |    252     |  49221   | (array([0], dtype=int32), array([19], dtype=int32)) |  (array([19]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    253     |  192538  | (array([0], dtype=int32), array([14], dtype=int32)) |  (array([14]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |    254     |  152048  | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    255     |  104524  | (array([0], dtype=int32), array([27], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([14], dtype=int32)) |     False      |
# |    256     |  170761  | (array([0], dtype=int32), array([30], dtype=int32)) |  (array([20]),) |   1    | (array([0], dtype=int32), array([36], dtype=int32)) |     False      |
# |    257     |  53165   | (array([0], dtype=int32), array([34], dtype=int32)) |  (array([34]),) |   1    | (array([0], dtype=int32), array([34], dtype=int32)) |      True      |
# |    258     |  209736  | (array([0], dtype=int32), array([21], dtype=int32)) |  (array([21]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    259     |  82810   | (array([0], dtype=int32), array([30], dtype=int32)) |  (array([22]),) |   1    |  (array([0], dtype=int32), array([2], dtype=int32)) |     False      |
# |    260     |  175387  | (array([0], dtype=int32), array([29], dtype=int32)) |  (array([29]),) |   1    |  (array([0], dtype=int32), array([1], dtype=int32)) |     False      |
# |    261     |  124347  | (array([0], dtype=int32), array([28], dtype=int32)) |  (array([28]),) |   1    | (array([0], dtype=int32), array([32], dtype=int32)) |     False      |
# |    262     |  108915  | (array([0], dtype=int32), array([22], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    263     |  180891  | (array([0], dtype=int32), array([22], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([35], dtype=int32)) |     False      |
# |    264     |  109280  | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    265     |  171280  |  (array([0], dtype=int32), array([3], dtype=int32)) |  (array([3]),)  |   1    |  (array([0], dtype=int32), array([8], dtype=int32)) |     False      |
# |    266     |  116827  | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    | (array([0], dtype=int32), array([36], dtype=int32)) |     False      |
# |    267     |  91945   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |      True      |
# |    268     |  223573  |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    | (array([0], dtype=int32), array([28], dtype=int32)) |     False      |
# |    269     |  193876  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    270     |  126028  | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    | (array([0], dtype=int32), array([35], dtype=int32)) |     False      |
# |    271     |  113473  | (array([0], dtype=int32), array([39], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([28], dtype=int32)) |     False      |
# |    272     |  205666  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([40], dtype=int32)) |     False      |
# |    273     |  64326   | (array([0], dtype=int32), array([26], dtype=int32)) |  (array([26]),) |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |    274     |  82861   | (array([0], dtype=int32), array([39], dtype=int32)) |  (array([39]),) |   1    | (array([0], dtype=int32), array([34], dtype=int32)) |     False      |
# |    275     |   7937   | (array([0], dtype=int32), array([31], dtype=int32)) |  (array([31]),) |   1    | (array([0], dtype=int32), array([27], dtype=int32)) |     False      |
# |    276     |  136577  | (array([0], dtype=int32), array([38], dtype=int32)) |  (array([38]),) |   1    | (array([0], dtype=int32), array([27], dtype=int32)) |     False      |
# |    277     |  50997   | (array([0], dtype=int32), array([22], dtype=int32)) |  (array([22]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |    278     |  57334   | (array([0], dtype=int32), array([34], dtype=int32)) |  (array([34]),) |   1    | (array([0], dtype=int32), array([23], dtype=int32)) |     False      |
# |    279     |  61557   | (array([0], dtype=int32), array([19], dtype=int32)) |  (array([19]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |    280     |  36108   |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([8]),)  |   1    | (array([0], dtype=int32), array([22], dtype=int32)) |     False      |
# |    281     |   2775   |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([0]),)  |   1    | (array([0], dtype=int32), array([28], dtype=int32)) |     False      |
# |    282     |  58139   | (array([0], dtype=int32), array([27], dtype=int32)) |  (array([27]),) |   1    |  (array([0], dtype=int32), array([6], dtype=int32)) |     False      |
# |    283     |  22810   |  (array([0], dtype=int32), array([8], dtype=int32)) |  (array([22]),) |   1    | (array([0], dtype=int32), array([23], dtype=int32)) |     False      |
# |    284     |  121499  | (array([0], dtype=int32), array([39], dtype=int32)) |  (array([23]),) |   1    | (array([0], dtype=int32), array([40], dtype=int32)) |     False      |
# |    285     |  133679  |  (array([0], dtype=int32), array([1], dtype=int32)) |  (array([1]),)  |   1    | (array([0], dtype=int32), array([18], dtype=int32)) |     False      |
# |    286     |  25003   | (array([0], dtype=int32), array([39], dtype=int32)) |  (array([17]),) |   1    | (array([0], dtype=int32), array([38], dtype=int32)) |     False      |
# |    287     |  115239  | (array([0], dtype=int32), array([23], dtype=int32)) |  (array([23]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |    288     |   8776   | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([14], dtype=int32)) |     False      |
# |    289     |  170052  | (array([0], dtype=int32), array([10], dtype=int32)) |  (array([10]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |    290     |  73521   | (array([0], dtype=int32), array([14], dtype=int32)) |  (array([14]),) |   1    | (array([0], dtype=int32), array([40], dtype=int32)) |     False      |
# |    291     |  102279  | (array([0], dtype=int32), array([38], dtype=int32)) |  (array([38]),) |   1    | (array([0], dtype=int32), array([33], dtype=int32)) |     False      |
# |    292     |  114137  | (array([0], dtype=int32), array([20], dtype=int32)) |  (array([20]),) |   1    | (array([0], dtype=int32), array([26], dtype=int32)) |     False      |
# |    293     |  128905  | (array([0], dtype=int32), array([18], dtype=int32)) |  (array([18]),) |   1    |  (array([0], dtype=int32), array([3], dtype=int32)) |     False      |
# |    294     |  157342  | (array([0], dtype=int32), array([37], dtype=int32)) |  (array([37]),) |   1    | (array([0], dtype=int32), array([15], dtype=int32)) |     False      |
# |    295     |  185417  | (array([0], dtype=int32), array([35], dtype=int32)) |  (array([35]),) |   1    |  (array([0], dtype=int32), array([0], dtype=int32)) |     False      |
# |    296     |  214181  |  (array([0], dtype=int32), array([0], dtype=int32)) |  (array([0]),)  |   1    | (array([0], dtype=int32), array([26], dtype=int32)) |     False      |
# |    297     |  196018  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([14], dtype=int32)) |     False      |
# |    298     |  124346  | (array([0], dtype=int32), array([15], dtype=int32)) |  (array([15]),) |   1    | (array([0], dtype=int32), array([19], dtype=int32)) |     False      |
# +------------+----------+-----------------------------------------------------+-----------------+--------+-----------------------------------------------------+----------------+
# Total cases of neighbor label matches are: 15
# For test set label classification prediction results
# Statistics for dataset: reddit
# ---------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f743aa3c14f3> in <module>()
#       1 #Analysis for Citeseer Dataset
#       2 dataset = 'reddit'
# ----> 3 run_embed(dataset)
#
# <ipython-input-2-bb9e2e084fb5> in run_embed(dataset_name, save_stats)
#       6     #runnning simple classifier on deepwalk embeddings
#       7     simple_classify_f1(dataset_name,emb,splits_ratio=[0.1],save_stats=True)
# ----> 8     graph_classify_analysis(dataset_name,graph_stat=True)
#
# ~/trial_projects/embeddings/graph_embedding/evaluation/util_func.py in graph_classify_analysis(dataset_name, graph_stat)
#     243     print("---------------------------------")
#     244
# --> 245     for i in sorted(counts.keys()):
#     246         print("For degree "+str(i)+" total: "+str(counts_total[i])+" ("+str(int((counts_total[i]/total_test_nodes)*100))+"%) and wrong prediction: "+ str(counts[i])+"("+str(int(counts[i]/counts_total[i]*100))+"%)")
#
# TypeError: '<' not supported between instances of 'DegreeView' and 'int'
